# %%
import pandas as pd
import matplotlib as mat

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is AE19-246B
#
#  Directory of C:\Users\suraj\Documents\Data Science
#
# 08/02/2019  10:45 PM    <DIR>          .
# 08/02/2019  10:45 PM    <DIR>          ..
# 07/29/2019  07:59 PM    <DIR>          .ipynb_checkpoints
# 07/29/2019  08:05 PM    <DIR>          Data
# 04/11/2019  10:15 PM        45,307,733 health_associated_infections_hospitals.csv
# 12/09/2018  11:55 PM    <DIR>          Kaggle
# 07/23/2019  11:27 PM           368,044 Untitled.ipynb
# 08/02/2019  10:45 PM           677,921 Untitled1.ipynb
#                3 File(s)     46,353,698 bytes
#                5 Dir(s)  1,751,281,631,232 bytes free

# %%
df = pd.read_excel("Data/IRMS REPORTING 19K 17July19.xlsx")

# %%
df.head()
# Out:
#   AEFLAG  ATTACHMENTCOUNTS  BDAYSENTEREDTOCOMPLETED  \
# 0     No               NaN                      1.0
# 1     No               NaN                      1.0
# 2     No               NaN                      1.0
# 3     No               NaN                      3.0
# 4     No               NaN                      1.0
#
#    BDAYSENTEREDTOQSTCOMPLETED  BDAYSRECEIVEDTOENTERED CASEHANDLING  \
# 0                         1.0                     1.0          NaN
# 1                         1.0                     1.0          NaN
# 2                         1.0                     1.0          NaN
# 3                         3.0                     1.0          NaN
# 4                         1.0                     1.0          NaN
#
#   CASELANGUAGE  CASENUMBER CASEPRIORITY CASEREQUESTVIA  ... Entry Days  \
# 0      English  1-39374373       Normal            NaN  ...      1 Day
# 1      English  1-39375965       Normal            NaN  ...      1 Day
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19172 entries, 0 to 19171
# Data columns (total 81 columns):
# AEFLAG                            19172 non-null object
# ATTACHMENTCOUNTS                  17542 non-null float64
# BDAYSENTEREDTOCOMPLETED           19071 non-null float64
# BDAYSENTEREDTOQSTCOMPLETED        18325 non-null float64
# BDAYSRECEIVEDTOENTERED            19128 non-null float64
# CASEHANDLING                      17746 non-null object
# CASELANGUAGE                      19172 non-null object
# CASENUMBER                        19172 non-null object
# CASEPRIORITY                      18600 non-null object
# CASEREQUESTVIA                    17519 non-null object
# CASESOURCE                        18334 non-null object
# CASESTATUS                        19172 non-null object
# CASETYPE                          17541 non-null object
# CATEGORY                          19167 non-null object
# CITY                              8702 non-null object
# ...

# %%
df[df.CONFERENCEDATE = TRUE]
# Out:
#   File "<ipython-input-7-eb5774df7f18>", line 1
#     df[df.CONFERENCEDATE = TRUE]
#                          ^
# SyntaxError: invalid syntax

# %%
df.TOPIC.value_counts().plot()

# %%
df100 = df.head(100)[['CASENUMBER', 'Received Date Y/Q/M', 'Product Name', 'Disease Area']]

# %%
df[df['Product Name'] == 'vosoritide'] #returns df
# Out:
#       AEFLAG  ATTACHMENTCOUNTS  BDAYSENTEREDTOCOMPLETED  \
# 61        No               NaN                      1.0
# 65        No               NaN                     13.0
# 68        No               NaN                      3.0
# 75        No               NaN                      1.0
# 129       No               NaN                      3.0
# 203       No               NaN                      1.0
# 206       No               NaN                      5.0
# 233       No               NaN                      2.0
# 234       No               NaN                      1.0
# 247       No               NaN                      1.0
# 255       No               NaN                      6.0
# 274       No               NaN                      2.0
# 299       No               NaN                     10.0
# 311       No               NaN                      1.0
# 322       No               NaN                      2.0
# 349       No               NaN                      5.0
# ...

# %%
df[df['Product Name'] == 'vosoritide']['Product Name']  # returns series
df[df['Product Name'] == 'vosoritide']['Product Name'].str.len()
df[df['Product Name'] == 'vosoritide']['Product Name'].dtype
df[df['Product Name'] == 'vosoritide']['Product Name'].str.len()
df[df['Product Name'] == 'vosoritide']['Product Name'].str.len()
df[df['Product Name'] == 'vosoritide']['Product Name'].values
df[df['Product Name'] == 'vosoritide']['Product Name'].value_counts()
df[df['Product Name'] == 'vosoritide']['Product Name'].count()
df[df['Product Name'] == 'vosoritide']['Product Name'].name
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
df[df['Product Name'] == 'vosoritide']['Product Name']
# Out:
# 61       vosoritide
# 65       vosoritide
# 68       vosoritide
# 75       vosoritide
# 129      vosoritide
# 203      vosoritide
# 206      vosoritide
# 233      vosoritide
# 234      vosoritide
# 247      vosoritide
# 255      vosoritide
# 274      vosoritide
# 299      vosoritide
# 311      vosoritide
# 322      vosoritide
# 349      vosoritide
# 361      vosoritide
# 370      vosoritide
# 376      vosoritide
# 378      vosoritide
# 379      vosoritide
# 384      vosoritide
# 394      vosoritide
# 400      vosoritide
# 462      vosoritide
# 468      vosoritide
# 504      vosoritide
# 520      vosoritide
# 521      vosoritide
# 522      vosoritide
#             ...
# 18920    vosoritide
# 18938    vosoritide
# 18976    vosoritide
# 18977    vosoritide
# 18978    vosoritide
# 18986    vosoritide
# 18988    vosoritide
# 18998    vosoritide
# 18999    vosoritide
# 19000    vosoritide
# 19001    vosoritide
# 19002    vosoritide
# 19003    vosoritide
# 19012    vosoritide
# ...

# %%
df = df[[u'CASENUMBER',u'CATEGORY', u'COMPLETEDDATE', u'CONTACTCLASS',u'CONTACTTYPE',
       u'COUNTRY', u'COUNTRYNAME', u'DEGREE', u'GMIUSEONLY', u'NOTES', u'PRODUCT', u'PRODUCTCATEGORY (2)', u'PRODUCTNAME',
u'QUESTION',u'QUESTIONID', u'RECEIVEDDATE', u'REGION',
       u'REQUESTORTYPE', u'RESOLUTION', u'RESOLUTIONCATEGORY',
       u'RESOLUTIONTYPE', u'RESPONSE',u'SPECIALTY',u'TOPIC', u'GMI Use Only',u'ProductCategory', u'Received Date Y/Q/M',u'Resolution Category', u'Product Name',
       u'Disease Area']]

# %%
df
# Out:
#        CASENUMBER                    CATEGORY       COMPLETEDDATE  \
# 0      1-39374373                Availability 2015-01-05 00:00:00
# 1      1-39375965                Availability 2015-01-05 00:00:00
# 2      1-39377345                Dosing/Admin 2015-01-05 00:00:00
# 3      1-39393962            Indication/Usage 2015-01-09 00:00:00
# 4      1-39395191                Availability 2015-01-07 00:00:00
# 5      1-39407983                Availability 2015-01-08 00:00:00
# 6      1-39409871            Indication/Usage 2015-01-08 00:00:00
# 7      1-39410054                Availability 2015-01-08 00:00:00
# 8      1-39420823                Availability 2015-01-13 00:00:00
# 9      1-39420881                Availability 2015-01-09 00:00:00
# 10     1-39438418            Indication/Usage 2015-01-12 00:00:00
# 11     1-39459955          Special Population 2015-01-14 00:00:00
# 12     1-39459993            Indication/Usage 2015-01-14 00:00:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19172 entries, 0 to 19171
# Data columns (total 30 columns):
# CASENUMBER             19172 non-null object
# CATEGORY               19167 non-null object
# COMPLETEDDATE          19071 non-null datetime64[ns]
# CONTACTCLASS           17542 non-null object
# CONTACTTYPE            17542 non-null object
# COUNTRY                19172 non-null object
# COUNTRYNAME            19172 non-null object
# DEGREE                 8653 non-null object
# GMIUSEONLY             176 non-null object
# NOTES                  13312 non-null object
# PRODUCT                19169 non-null object
# PRODUCTCATEGORY (2)    15782 non-null object
# PRODUCTNAME            15782 non-null object
# QUESTION               17542 non-null object
# QUESTIONID             19172 non-null int64
# RECEIVEDDATE           19138 non-null datetime64[ns]
# REGION                 19172 non-null object
# REQUESTORTYPE          19171 non-null object
# ...

# %%
df_apac = df[df.REGION == 'APAC']

# %%
df_apac
# Out:
#       CASENUMBER                         CATEGORY       COMPLETEDDATE  \
# 792   AP15-00011                  Clinical Trials 2015-11-02 15:38:05
# 793   AP15-00012                             Labs 2015-11-01 17:45:24
# 794   AP15-00012                             Labs 2015-11-01 17:45:24
# 795   AP15-00012      Request Published Materials 2015-11-01 17:45:24
# 796   AP15-00015                       Monitoring 2015-11-18 18:15:12
# 797   AP15-00016                       Monitoring 2015-11-01 17:46:19
# 798   AP15-00017                          Disease 2015-12-10 13:57:43
# 799   AP15-00018                            Other 2015-11-05 01:03:05
# 800   AP15-00019                            Other 2015-11-12 15:06:19
# 801   AP15-00020                  Clinical Trials 2015-11-18 14:34:31
# 802   AP15-00022                  Clinical Trials 2015-12-08 18:47:28
# 803   AP15-00023                     Availability 2015-12-07 19:46:07
# ...

# %%
df_apac.groupby(['PRODUCTNAME', 'Received Date Y/Q/M']).size().sort_values(ascending=False)
# Out:
# PRODUCTNAME           Received Date Y/Q/M
# KUVAN                 [2019].[Q2].[May]      43
#                       [2019].[Q2].[Jun]      26
# BRINEURA              [2019].[Q2].[Jun]      18
# drisapersen           [2015].[Q3].[Sep]      17
# BRINEURA              [2017].[Q2].[May]      17
# pegvaliase            [2018].[Q4].[Nov]      16
# vosoritide            [2018].[Q3].[Sep]      14
# pegvaliase            [2019].[Q2].[May]      14
# KUVAN                 [2019].[Q3].[Jul]      13
# vosoritide            [2018].[Q2].[Apr]      12
# drisapersen           [2015].[Q2].[Apr]      12
# BMN 270               [2017].[Q4].[Dec]      12
# VIMIZIM               [2019].[Q2].[May]      12
# vosoritide            [2017].[Q2].[May]      11
# VIMIZIM               [2017].[Q3].[Aug]      11
# BRINEURA              [2019].[Q2].[May]      11
# vosoritide            [2016].[Q1].[Jan]      11
# BRINEURA              [2017].[Q3].[Sep]      11
# vosoritide            [2017].[Q4].[Dec]      10
# ...

# %%
df_region_indexed = df.set_index(['REGION'])

# %%
#df.plot(x='Received Date Y/Q/M', y='QUESTIONID', kind='scatter')

# %%
df_indexed = df.set_index(['QUESTIONID'])

# %%
df_apac_kuvan = df[(df.REGION == 'APAC') & (df.PRODUCT == 'KUVAN')]

# %%
df_apac_kuvan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 215 entries, 818 to 9946
# Data columns (total 30 columns):
# CASENUMBER             215 non-null object
# CATEGORY               215 non-null object
# COMPLETEDDATE          215 non-null datetime64[ns]
# CONTACTCLASS           212 non-null object
# CONTACTTYPE            212 non-null object
# COUNTRY                215 non-null object
# COUNTRYNAME            215 non-null object
# DEGREE                 75 non-null object
# GMIUSEONLY             0 non-null object
# NOTES                  145 non-null object
# PRODUCT                215 non-null object
# PRODUCTCATEGORY (2)    215 non-null object
# PRODUCTNAME            215 non-null object
# QUESTION               212 non-null object
# QUESTIONID             215 non-null int64
# RECEIVEDDATE           215 non-null datetime64[ns]
# REGION                 215 non-null object
# REQUESTORTYPE          215 non-null object
# RESOLUTION             212 non-null object
# ...

# %%
df_apac_kuvan.tail()
# Out:
#       CASENUMBER      CATEGORY       COMPLETEDDATE CONTACTCLASS  \
# 2173  AP19-00237  Availability 2019-07-12 00:36:13   Pharmacist
# 2181  AP19-00243  Availability 2019-07-15 23:40:14    Other HCP
# 2279   AU0000178  Availability 2015-09-30 00:00:00          NaN
# 7611   GB0000478  Availability 2015-07-09 00:00:00          NaN
# 9946   MY0000005         Other 2015-10-15 00:00:00          NaN
#
#               CONTACTTYPE COUNTRY COUNTRYNAME DEGREE GMIUSEONLY NOTES  ...  \
# 2173  Health Professional      AU   Australia    NaN        NaN   NaN  ...
# 2181  Health Professional      AU   Australia    NaN        NaN   NaN  ...
# 2279                  NaN      SG   Singapore    NaN        NaN   NaN  ...
# 7611                  NaN      PK    Pakistan    NaN        NaN   NaN  ...
# 9946                  NaN      MY    Malaysia    NaN        NaN   NaN  ...
#
#      RESOLUTIONTYPE                                           RESPONSE  \
# ...

# %%
df_apac_kuvan[(df_apac_kuvan.COMPLETEDDATE.dt.hour == 15) & (df_apac_kuvan.COUNTRY == 'IN')].sort_values(by=['RECEIVEDDATE'])
# Out:
#       CASENUMBER      CATEGORY       COMPLETEDDATE CONTACTCLASS  \
# 1177  AP17-00108  Availability 2017-05-15 15:35:57           MD
# 1867  AP19-00025  Availability 2019-02-24 15:22:05     Consumer
#
#               CONTACTTYPE COUNTRY COUNTRYNAME DEGREE GMIUSEONLY  \
# 1177  Health Professional      IN       India     MD        NaN
# 1867             Consumer      IN       India    NaN        NaN
#
#                                                   NOTES  ... RESOLUTIONTYPE  \
# 1177  Sean Brady - 5/15/2017 2:44:36 PM\nEmail Priva...  ...       Transfer
# 1867  Weng Fong Wong - 2/25/2019 10:21:27 AM\nClarif...  ...    MI Response
#
#                                                RESPONSE SPECIALTY  \
# 1177  Preferred contact method: Email\n\n\tUse “Resp...       NaN
# 1867  Responded to customer using:\n"Availability Co...       NaN
#
#                       TOPIC  GMI Use Only   ProductCategory  \
# 1177  Purchase Product/Cost           NaN  Marketed Product
# ...

# %%
df_apac_kuvan[(df_apac_kuvan.COMPLETEDDATE.dt.hour == 15) & (df_apac_kuvan.COUNTRY == 'IN')].sort_values(by=['COMPLETEDDATE'])
# Out:
#       CASENUMBER      CATEGORY       COMPLETEDDATE CONTACTCLASS  \
# 1177  AP17-00108  Availability 2017-05-15 15:35:57           MD
# 1867  AP19-00025  Availability 2019-02-24 15:22:05     Consumer
#
#               CONTACTTYPE COUNTRY COUNTRYNAME DEGREE GMIUSEONLY  \
# 1177  Health Professional      IN       India     MD        NaN
# 1867             Consumer      IN       India    NaN        NaN
#
#                                                   NOTES  ... RESOLUTIONTYPE  \
# 1177  Sean Brady - 5/15/2017 2:44:36 PM\nEmail Priva...  ...       Transfer
# 1867  Weng Fong Wong - 2/25/2019 10:21:27 AM\nClarif...  ...    MI Response
#
#                                                RESPONSE SPECIALTY  \
# 1177  Preferred contact method: Email\n\n\tUse “Resp...       NaN
# 1867  Responded to customer using:\n"Availability Co...       NaN
#
#                       TOPIC  GMI Use Only   ProductCategory  \
# 1177  Purchase Product/Cost           NaN  Marketed Product
# ...

# %%
MaskIndia = df.COUNTRYNAME.str.contains('In')
df[MaskIndia]
# Out:
#        CASENUMBER                     CATEGORY       COMPLETEDDATE  \
# 772   2015-039342                 Availability 2015-09-22 00:00:00
# 799    AP15-00018                        Other 2015-11-05 01:03:05
# 802    AP15-00022              Clinical Trials 2015-12-08 18:47:28
# 821    AP15-00033                      Disease 2016-01-07 18:43:48
# 834    AP16-00004              Clinical Trials 2016-01-11 17:31:13
# 846    AP16-00017              Clinical Trials 2016-09-06 06:09:19
# 848    AP16-00019                 Dosing/Admin 2016-04-06 19:06:37
# 849    AP16-00019                 Dosing/Admin 2016-04-06 19:06:37
# 860    AP16-00027              Clinical Trials 2016-04-17 22:18:43
# 864    AP16-00030              Clinical Trials 2016-04-20 19:03:27
# 865    AP16-00030                 Availability 2016-04-20 19:03:27
# 868    AP16-00033                 Availability 2016-04-24 20:06:33
# 873    AP16-00037                 Availability 2016-04-27 19:09:31
# ...

# %%
#df_apac_kuvan[df_apac_kuvan.DEGREE.notnull()].DEGREE.value_counts()
df_apac_kuvan[df_apac_kuvan.DEGREE.notnull()].COUNTRYNAME.value_counts()
#df_apac_kuvan[df_apac_kuvan.DEGREE.notnull()].DEGREE.value_counts()
# Out:
# Australia      45
# India          10
# China           5
# Malaysia        5
# New Zealand     4
# Taiwan          3
# Indonesia       2
# Singapore       1
# Name: COUNTRYNAME, dtype: int64

# %%
df_apac_kuvan[df_apac_kuvan.NOTES.notnull()]
# Out:
#       CASENUMBER                         CATEGORY       COMPLETEDDATE  \
# 818   AP15-00030                     Availability 2015-12-10 19:16:38
# 822   AP16-00002                     Availability 2016-01-04 20:32:43
# 837   AP16-00007                     Availability 2016-01-26 12:35:10
# 842   AP16-00013                          Disease 2016-03-16 09:54:15
# 843   AP16-00014                     Availability 2016-03-07 19:28:41
# 844   AP16-00015                Storage/Stability 2016-03-13 18:13:19
# 845   AP16-00016                Storage/Stability 2016-03-21 14:49:16
# 847   AP16-00018                     Availability 2016-03-29 15:29:42
# 852   AP16-00021                Storage/Stability 2016-04-15 10:20:57
# 861   AP16-00028                     Availability 2016-04-20 18:17:22
# 871   AP16-00036                     Availability 2016-04-26 18:36:28
# 872   AP16-00036                            Other 2016-04-26 18:36:28
# ...

# %%
#df_apac_kuvan[df_apac_kuvan.COUNTRYNAME == 'JAPAN']
df_apac_kuvan.COUNTRYNAME.value_counts()
# Out:
# Australia             131
# China                  27
# India                  19
# Taiwan                  9
# New Zealand             7
# Malaysia                7
# Hong Kong               4
# Singapore               4
# Indonesia               2
# Pakistan                2
# Not Provided            1
# Bangladesh              1
# Korea, Republic of      1
# Name: COUNTRYNAME, dtype: int64

# %%
df_indexed = df.set_index(['CASENUMBER', 'QUESTIONID', 'PRODUCTNAME', 'REGION']).sort_index()

# %%
df_indexed.info()

# %%
df_indexed.reset_index(['CASENUMBER', 'QUESTIONID', 'PRODUCTNAME', 'REGION'])

# %%
df_indexed.reset_index(['CASENUMBER', 'QUESTIONID', 'PRODUCTNAME', 'REGION'])

# %%
df_indexed.columns

# %%
df.values

# %%
df.dtypes

# %%
df.columns

# %%
df.axes

# %%
df.ndim

# %%
df.size

# %%
df.shape

# %%
df.empty

# %%
df.

# %%
df
# Out:
#        CASENUMBER                    CATEGORY       COMPLETEDDATE  \
# 0      1-39374373                Availability 2015-01-05 00:00:00
# 1      1-39375965                Availability 2015-01-05 00:00:00
# 2      1-39377345                Dosing/Admin 2015-01-05 00:00:00
# 3      1-39393962            Indication/Usage 2015-01-09 00:00:00
# 4      1-39395191                Availability 2015-01-07 00:00:00
# 5      1-39407983                Availability 2015-01-08 00:00:00
# 6      1-39409871            Indication/Usage 2015-01-08 00:00:00
# 7      1-39410054                Availability 2015-01-08 00:00:00
# 8      1-39420823                Availability 2015-01-13 00:00:00
# 9      1-39420881                Availability 2015-01-09 00:00:00
# 10     1-39438418            Indication/Usage 2015-01-12 00:00:00
# 11     1-39459955          Special Population 2015-01-14 00:00:00
# 12     1-39459993            Indication/Usage 2015-01-14 00:00:00
# ...
