# %%
import pandas as pd

# %%
data = pd.read_csv("health_associated_infections_hospitals.csv")

# %%
data
# Out:
#         Provider ID                                      Hospital Name  \
# 0            190164                             BYRD REGIONAL HOSPITAL
# 1            190164                             BYRD REGIONAL HOSPITAL
# 2            190164                             BYRD REGIONAL HOSPITAL
# 3            190164                             BYRD REGIONAL HOSPITAL
# 4            190164                             BYRD REGIONAL HOSPITAL
# 5            190164                             BYRD REGIONAL HOSPITAL
# 6            190164                             BYRD REGIONAL HOSPITAL
# 7            190164                             BYRD REGIONAL HOSPITAL
# 8            190164                             BYRD REGIONAL HOSPITAL
# 9            190164                             BYRD REGIONAL HOSPITAL
# 10           190164                             BYRD REGIONAL HOSPITAL
# 11           190164                             BYRD REGIONAL HOSPITAL
# ...

# %%
data.describe()
# Out:
#          Provider ID       ZIP Code
# count  172224.000000  172224.000000
# mean   268093.926839   54010.797032
# std    157060.442696   26903.286235
# min     10001.000000     603.000000
# 25%    140181.750000   33019.750000
# 50%    260043.500000   55410.500000
# 75%    390212.500000   76051.750000
# max    670124.000000   99929.000000

# %%
data.loc[data['State'].str.contains('CA')].describe()
# Out:
#        Provider ID  ZIP Code
# count          0.0       0.0
# mean           NaN       NaN
# std            NaN       NaN
# min            NaN       NaN
# 25%            NaN       NaN
# 50%            NaN       NaN
# 75%            NaN       NaN
# max            NaN       NaN

# %%
data['Measure Name'].unique()
# Out:
# array(['Central Line Associated Bloodstream Infection (ICU + select Wards): Lower Confidence Limit',
#        'Central Line Associated Bloodstream Infection (ICU + select Wards): Upper Confidence Limit',
#        'Central Line Associated Bloodstream Infection: Number of Device Days',
#        'Central Line Associated Bloodstream Infection (ICU + select Wards): Predicted Cases',
#        'Central Line Associated Bloodstream Infection (ICU + select Wards): Observed Cases',
#        'Central Line Associated Bloodstream Infection (ICU + select Wards)',
#        'Catheter Associated Urinary Tract Infections (ICU + select Wards): Lower Confidence Limit',
#        'Catheter Associated Urinary Tract Infections (ICU + select Wards): Upper Confidence Limit',
#        'Catheter Associated Urinary Tract Infections (ICU + select Wards): Number of Urinary Catheter Days',
#        'Catheter Associated Urinary Tract Infections (ICU + select Wards): Predicted Cases',
# ...

# %%
data['Measure Name'].describe()
# Out:
# count                                                172224
# unique                                                   36
# top       Catheter Associated Urinary Tract Infections (...
# freq                                                   4784
# Name: Measure Name, dtype: object

# %%
data['count'] = 1
#group_data = data.groupby(['Measure Name']).count()
group_data = data['Measure Name'].groupby(data['State']).count()

group_data
# Out:
# State
# AK      792
# AL     3276
# AR     2736
# AS       36
# AZ     2772
# CA    12204
# CO     2952
# CT     1116
# DC      288
# DE      252
# FL     6624
# GA     4752
# GU       72
# HI      828
# IA     4176
# ID     1512
# IL     6480
# IN     4320
# KS     4896
# KY     3276
# LA     4248
# MA     2232
# MD     1764
# ME     1188
# MI     4716
# MN     4680
# MO     4032
# MP       36
# MS     3420
# MT     2232
# NC     3780
# ND     1584
# NE     3204
# NH      936
# NJ     2376
# NM     1476
# NV     1260
# NY     6120
# OH     6048
# OK     4464
# OR     2160
# PA     6192
# PR     1872
# RI      360
# SC     2160
# SD     2088
# TN     3816
# TX    14580
# UT     1656
# VA     3024
# VI       72
# VT      504
# WA     3276
# WI     4536
# WV     1764
# WY     1008
# Name: Measure Name, dtype: int64

# %%
data.State.unique()
# Out:
# array(['LA', 'NE', 'NV', 'SD', 'FL', 'IA', 'MN', 'NH', 'PA', 'TX', 'AZ',
#        'DC', 'KS', 'MT', 'NJ', 'PR', 'OH', 'AK', 'MA', 'MO', 'ND', 'IN',
#        'NY', 'MS', 'TN', 'AL', 'OK', 'CA', 'KY', 'MI', 'WI', 'AR', 'GA',
#        'VT', 'MD', 'NC', 'OR', 'CO', 'ME', 'SC', 'VA', 'ID', 'IL', 'RI',
#        'WA', 'UT', 'CT', 'WY', 'WV', 'NM', 'HI', 'AS', 'VI', 'DE', 'GU',
#        'MP'], dtype=object)

# %%
len(data)
# Out:
# 172224

# %%
df = data

# %%
# Gather columns into rows
# pd.melt(df)

# Spread rows into columns
# df.pivot(columns='var', values='val')

# Append rows of DataFrames
# pd.concat([df1,df2])

# Append columns of DataFrames
# pd.concat([df1,df2], axis=1)

# df.sort_values('ZIP Code')
df.sort_values('ZIP Code', ascending=False)
# Out:
#         Provider ID                     Hospital Name  \
# 138980        21305           WRANGELL MEDICAL CENTER
# 138969        21305           WRANGELL MEDICAL CENTER
# 138975        21305           WRANGELL MEDICAL CENTER
# 138974        21305           WRANGELL MEDICAL CENTER
# 138973        21305           WRANGELL MEDICAL CENTER
# 138972        21305           WRANGELL MEDICAL CENTER
# 138971        21305           WRANGELL MEDICAL CENTER
# 138970        21305           WRANGELL MEDICAL CENTER
# 138968        21305           WRANGELL MEDICAL CENTER
# 138977        21305           WRANGELL MEDICAL CENTER
# 138967        21305           WRANGELL MEDICAL CENTER
# 138966        21305           WRANGELL MEDICAL CENTER
# 138965        21305           WRANGELL MEDICAL CENTER
# 138964        21305           WRANGELL MEDICAL CENTER
# 138963        21305           WRANGELL MEDICAL CENTER
# 138962        21305           WRANGELL MEDICAL CENTER
# ...

# %%
# Row Subsetting

# df[df.State =="CA"]
df[df['State'] =="CA"]
# Out:
#         Provider ID             Hospital Name              Address  \
# 1764          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1765          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1766          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1767          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1768          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1769          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1770          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1771          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1772          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1773          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1774          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1775          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# 1776          50308        EL CAMINO HOSPITAL      2500 GRANT ROAD
# ...

# %% [markdown]
# Column Subsetting

# %%
data.iloc[2:6,[2,9,3,6]]
# Out:
#               Address       Measure ID       City County Name
# 2  1020 FERTITTA BLVD  HAI-1-DOPC-DAYS  LEESVILLE      VERNON
# 3  1020 FERTITTA BLVD  HAI-1-ELIGCASES  LEESVILLE      VERNON
# 4  1020 FERTITTA BLVD  HAI-1-NUMERATOR  LEESVILLE      VERNON
# 5  1020 FERTITTA BLVD        HAI-1-SIR  LEESVILLE      VERNON

# %%
data.loc[data['State'] == 'CA', ["State", 'Phone Number']].head()
# Out:
#      State    Phone Number
# 1764    CA  (650) 940-7000
# 1765    CA  (650) 940-7000
# 1766    CA  (650) 940-7000
# 1767    CA  (650) 940-7000
# 1768    CA  (650) 940-7000

# %%
#data.iloc[:,[1,5]]
data.iloc[:,1:5]
# Out:
#                                             Hospital Name             Address  \
# 0                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 1                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 2                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 3                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 4                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 5                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 6                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 7                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 8                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 9                                  BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# 10                                 BYRD REGIONAL HOSPITAL  1020 FERTITTA BLVD
# ...

# %%
# df.State.unique()
df.State.nunique()
# Out:
# 56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172224 entries, 0 to 172223
# Data columns (total 16 columns):
# Provider ID             172224 non-null int64
# Hospital Name           172224 non-null object
# Address                 172224 non-null object
# City                    172224 non-null object
# State                   172224 non-null object
# ZIP Code                172224 non-null int64
# County Name             171828 non-null object
# Phone Number            172224 non-null object
# Measure Name            172224 non-null object
# Measure ID              172224 non-null object
# Compared to National    172224 non-null object
# Score                   172224 non-null object
# Footnote                103838 non-null object
# Measure Start Date      172224 non-null object
# Measure End Date        172224 non-null object
# count                   172224 non-null int64
# dtypes: int64(3), object(13)
# memory usage: 21.0+ MB

# %%
group_data
# Out:
# Measure Name
# Catheter Associated Urinary Tract Infections (ICU + select Wards)                                     4784
# Catheter Associated Urinary Tract Infections (ICU + select Wards): Lower Confidence Limit             4784
# Catheter Associated Urinary Tract Infections (ICU + select Wards): Number of Urinary Catheter Days    4784
# Catheter Associated Urinary Tract Infections (ICU + select Wards): Observed Cases                     4784
# Catheter Associated Urinary Tract Infections (ICU + select Wards): Predicted Cases                    4784
# Catheter Associated Urinary Tract Infections (ICU + select Wards): Upper Confidence Limit             4784
# Central Line Associated Bloodstream Infection (ICU + select Wards)                                    4784
# Central Line Associated Bloodstream Infection (ICU + select Wards): Lower Confidence Limit            4784
# Central Line Associated Bloodstream Infection (ICU + select Wards): Observed Cases                    4784
# ...

# %%
data['State'].unique()
# Out:
# array(['LA', 'NE', 'NV', 'SD', 'FL', 'IA', 'MN', 'NH', 'PA', 'TX', 'AZ',
#        'DC', 'KS', 'MT', 'NJ', 'PR', 'OH', 'AK', 'MA', 'MO', 'ND', 'IN',
#        'NY', 'MS', 'TN', 'AL', 'OK', 'CA', 'KY', 'MI', 'WI', 'AR', 'GA',
#        'VT', 'MD', 'NC', 'OR', 'CO', 'ME', 'SC', 'VA', 'ID', 'IL', 'RI',
#        'WA', 'UT', 'CT', 'WY', 'WV', 'NM', 'HI', 'AS', 'VI', 'DE', 'GU',
#        'MP'], dtype=object)

# %%
len(data['State'].unique().tolist())
# Out:
# 56

# %%
order(data['State'].unique().tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-98f2962b0c4c> in <module>()
# ----> 1 order(data['State'].unique().tolist())
#
# NameError: name 'order' is not defined

# %%
data[["State"]].sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-421325c3db1e> in <module>()
# ----> 1 data[["State"]].sort()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
data.sort_values('State')
# Out:
#         Provider ID                       Hospital Name  \
# 121211        21308      NORTON SOUND REGIONAL HOSPITAL
# 44670         21304           PETERSBURG MEDICAL CENTER
# 44671         21304           PETERSBURG MEDICAL CENTER
# 138961        21305             WRANGELL MEDICAL CENTER
# 138962        21305             WRANGELL MEDICAL CENTER
# 138963        21305             WRANGELL MEDICAL CENTER
# 42443         21314               MT EDGECUMBE HOSPITAL
# 138964        21305             WRANGELL MEDICAL CENTER
# 42442         21314               MT EDGECUMBE HOSPITAL
# 42441         21314               MT EDGECUMBE HOSPITAL
# 42440         21314               MT EDGECUMBE HOSPITAL
# 44669         21304           PETERSBURG MEDICAL CENTER
# 42439         21314               MT EDGECUMBE HOSPITAL
# 42437         21314               MT EDGECUMBE HOSPITAL
# 42436         21314               MT EDGECUMBE HOSPITAL
# 42435         21314               MT EDGECUMBE HOSPITAL
# ...

# %%
data["State"].nunique()
# Out:
# 56

# %%
data.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-375e8115d44b> in <module>()
# ----> 1 data.len()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'len'

# %%
len(data)
# Out:
# 172224

# %%
data.describe()
# Out:
#          Provider ID       ZIP Code
# count  172224.000000  172224.000000
# mean   268093.926839   54010.797032
# std    157060.442696   26903.286235
# min     10001.000000     603.000000
# 25%    140181.750000   33019.750000
# 50%    260043.500000   55410.500000
# 75%    390212.500000   76051.750000
# max    670124.000000   99929.000000

# %% [raw]
# data.info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172224 entries, 0 to 172223
# Data columns (total 15 columns):
# Provider ID             172224 non-null int64
# Hospital Name           172224 non-null object
# Address                 172224 non-null object
# City                    172224 non-null object
# State                   172224 non-null object
# ZIP Code                172224 non-null int64
# County Name             171828 non-null object
# Phone Number            172224 non-null object
# Measure Name            172224 non-null object
# Measure ID              172224 non-null object
# Compared to National    172224 non-null object
# Score                   172224 non-null object
# Footnote                103838 non-null object
# Measure Start Date      172224 non-null object
# Measure End Date        172224 non-null object
# dtypes: int64(2), object(13)
# memory usage: 19.7+ MB
